# %% [markdown]
# # Dreambooth Personalized Image Generation

# %% [markdown]
# ## Setup and Installation

# %% [markdown]
# **Important**: We need to clone this forked diffusers repo, as it contains additional arguments / modifications to improve the results

# %%
# Install diffusers 
# !git clone https://github.com/ShivamShrirao/diffusers

# %cd diffusers/
# !pip install -e .

# For GPU efficiency
# !pip install bitsandbytes

# Install dreambooth requirements
# %cd /content/diffusers/examples/dreambooth/
# !pip install -r requirements.txt

# Accelerate environment
# !accelerate config default
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 20180, done.
# remote: Total 20180 (delta 0), reused 0 (delta 0), pack-reused 20180
# Receiving objects: 100% (20180/20180), 22.96 MiB | 6.36 MiB/s, done.
# Resolving deltas: 100% (14456/14456), done.
# /content/diffusers
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/diffusers
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (1.22.4)
# Collecting huggingface-hub>=0.13.2
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (2.27.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (6.1.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (3.10.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from diffusers==0.15.0.dev0) (2022.10.31)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (4.5.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.13.2->diffusers==0.15.0.dev0) (23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->diffusers==0.15.0.dev0) (3.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers==0.15.0.dev0) (3.4)
# Building wheels for collected packages: diffusers
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.15.0.dev0-0.editable-py3-none-any.whl size=11106 sha256=14d360c3d0967d33846dfcf8aef5df1cc44f93c8f173f1979bff7c49987aedf7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7qtjo83d/wheels/bd/1c/ea/a9c409b587aa6f3abca1bf1ce8eb592b2b541e5f26f5a4f44b
# Successfully built diffusers
# Installing collected packages: huggingface-hub, diffusers
# Successfully installed diffusers-0.15.0.dev0 huggingface-hub-0.13.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.37.2-py3-none-any.whl (84.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 MB 11.3 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.37.2
# /content/diffusers/examples/dreambooth
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting accelerate
#   Downloading accelerate-0.18.0-py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 KB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (0.15.1+cu118)
# Collecting transformers>=4.25.1
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 80.8 MB/s eta 0:00:00
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (2.12.1)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (3.1.2)
# Collecting safetensors
#   Downloading safetensors-0.3.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.0 MB/s eta 0:00:00
# Collecting xformers
#   Downloading xformers-0.0.18-cp39-cp39-manylinux2014_x86_64.whl (123.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (5.9.4)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (2.0.0+cu118)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from accelerate->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision->-r requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->-r requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (3.10.7)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (16.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.25.1->-r requirements.txt (line 3)) (0.13.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.6 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.25.1->-r requirements.txt (line 3)) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers>=4.25.1->-r requirements.txt (line 3)) (4.65.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->-r requirements.txt (line 4)) (0.2.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (2.17.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (67.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (3.20.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (0.40.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard->-r requirements.txt (line 5)) (1.53.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2->-r requirements.txt (line 6)) (2.1.2)
# Collecting pyre-extensions==0.0.23
#   Downloading pyre_extensions-0.0.23-py3-none-any.whl (11 kB)
# Collecting typing-inspect
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard->-r requirements.txt (line 5)) (6.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->-r requirements.txt (line 2)) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r requirements.txt (line 5)) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->-r requirements.txt (line 5)) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.4.0->accelerate->-r requirements.txt (line 1)) (1.3.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tokenizers, safetensors, mypy-extensions, ftfy, typing-inspect, transformers, pyre-extensions, xformers, accelerate
# Successfully installed accelerate-0.18.0 ftfy-6.1.1 mypy-extensions-1.0.0 pyre-extensions-0.0.23 safetensors-0.3.0 tokenizers-0.13.3 transformers-4.27.4 typing-inspect-0.8.0 xformers-0.0.18
# 2023-04-08 08:51:40.455000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %% [markdown]
# ## Which GPU can we use?
#
# - Typically we have 16GB GPUs on Colab (Free Version)
# - The below settings should be fine to run the code. Otherwise you might want to utilize xformers memory efficient attention (as described [here](https://github.com/huggingface/diffusers/tree/main/examples/dreambooth))

# %%
# !nvidia-smi
# Out:
# Sat Apr  8 08:41:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Time to upload the samples

# %%
# %cd /content
print("Make sure you put the images into the newly created directory!")
# !mkdir images
# Out:
# /content
# Make sure you put the images into the newly created directory!

# %% [markdown]
# ## Fine-tuning

# %% [markdown]
# ### Explanation of the most important args:
#
# | Argument | Description |
# | --- | --- |
# | instance_data_dir | Directory of the sample images |
# | instance_prompt | Prompt with the special token like [V], zwx, sks... |
# | with_prior_preservation | Used to avoid overfitting and language-drift |
# | num_class_images | Number of generated images (prior) |
# | class_prompt | Used together with prior preservation - type of generated samples to avoid prior loss |
# | use_8bit_adam | Quantized optimizer to reduce GPU memory (from bitsandbytes using reduced precision) |
# | mixed_precision | Another accelerator to reduce data type precision |
# | pretrained_vae_name_or_path | Custom autoencoder to improve eyes and faces |
#
#
# - There are also other scripts like train_dreambooth_lora.py
# - The actual values are based on a mix of experimentation and different diffusers tutorials

# %%
# %cd /content
# %env MODEL_NAME=runwayml/stable-diffusion-v1-5
# %env INSTANCE_DIR=/content/images/
# %env OUTPUT_DIR=outputs/
# %env CLASS_DIR=/content/diffusers/examples/dreambooth/person/


# !accelerate launch diffusers/examples/dreambooth/train_dreambooth.py \
    --pretrained_model_name_or_path=$MODEL_NAME  \
    --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
    --instance_data_dir=$INSTANCE_DIR \
    --output_dir=$OUTPUT_DIR \
    --class_data_dir=$CLASS_DIR \
    --with_prior_preservation --prior_loss_weight=1.0 \
    --instance_prompt="photo of zwx person" \
    --class_prompt="photo of person" \
    --resolution=512 \
    --train_batch_size=1 \
    --gradient_accumulation_steps=1 --gradient_checkpointing \
    --use_8bit_adam \
    --mixed_precision="fp16" \
    --learning_rate=1e-6 \
    --lr_scheduler="constant" \
    --lr_warmup_steps=0 \
    --num_class_images=300 \
    --max_train_steps=1000
# Out:
# /content
# env: MODEL_NAME=runwayml/stable-diffusion-v1-5
# env: INSTANCE_DIR=/content/images/
# env: OUTPUT_DIR=outputs/
# env: CLASS_DIR=/content/diffusers/examples/dreambooth/person/
# 2023-04-08 08:52:29.668594: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-04-08 08:52:33.797416: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/accelerate/accelerator.py:249: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
# Downloading (…)lve/main/config.json: 100% 547/547 [00:00<00:00, 93.9kB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:01<00:00, 288MB/s]
# /usr/local/lib/python3.9/dist-packages/safetensors/torch.py:99: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   with safe_open(filename, framework="pt", device=device) as f:
# /usr/local/lib/python3.9/dist-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# /usr/local/lib/python3.9/dist-packages/torch/storage.py:899: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = cls(wrap_storage=untyped_storage)
# Downloading (…)ain/model_index.json: 100% 543/543 [00:00<00:00, 92.3kB/s]
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading model.safetensors:   0% 0.00/1.22G [00:00<?, ?B/s]
#
# Downloading model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 55.0kB/s]
# Fetching 15 files:   7% 1/15 [00:00<00:03,  3.56it/s]
#
#
# Downloading (…)_checker/config.json:   0% 0.00/4.72k [00:00<?, ?B/s]
#
#
#
# Downloading (…)_checker/config.json: 100% 4.72k/4.72k [00:00<00:00, 345kB/s]
#
#
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 34.5kB/s]
#
#
#
#
# Downloading (…)_encoder/config.json:   0% 0.00/617 [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 7.44kB/s]
# Downloading (…)_encoder/config.json: 100% 617/617 [00:00<00:00, 18.7kB/s]
#
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 10.1MB/s]
#
# Downloading model.safetensors:   3% 31.5M/1.22G [00:00<00:09, 127MB/s]
#
#
# Downloading (…)okenizer_config.json: 100% 806/806 [00:00<00:00, 216kB/s]
#
#
# Downloading model.safetensors:   2% 10.5M/492M [00:00<00:15, 30.3MB/s]
# Downloading model.safetensors:   4% 52.4M/1.22G [00:00<00:07, 149MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
#
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading model.safetensors:   7% 83.9M/1.22G [00:00<00:05, 201MB/s]
#
# Downloading model.safetensors:   4% 21.0M/492M [00:00<00:10, 46.9MB/s]
#
#
#
#
#
# Downloading (…)819/unet/config.json: 100% 743/743 [00:00<00:00, 222kB/s]
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 12.3MB/s]
#
#
#
#
# Downloading (…)ch_model.safetensors:   3% 10.5M/335M [00:00<00:05, 63.0MB/s]
#
# Downloading model.safetensors:   6% 31.5M/492M [00:00<00:07, 60.8MB/s]
# Downloading model.safetensors:   9% 105M/1.22G [00:00<00:06, 174MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 10.5M/3.44G [00:00<01:21, 42.1MB/s]
#
#
#
#
# Downloading (…)d819/vae/config.json: 100% 547/547 [00:00<00:00, 163kB/s]
#
#
# Downloading model.safetensors:   9% 41.9M/492M [00:00<00:06, 68.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:   6% 21.0M/335M [00:00<00:04, 69.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 21.0M/3.44G [00:00<00:58, 58.4MB/s]
# Downloading model.safetensors:  10% 126M/1.22G [00:00<00:08, 135MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13% 41.9M/335M [00:00<00:03, 93.8MB/s]
#
# Downloading model.safetensors:  13% 62.9M/492M [00:00<00:05, 83.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 31.5M/3.44G [00:00<00:54, 62.6MB/s]
# Downloading model.safetensors:  12% 147M/1.22G [00:01<00:08, 130MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  19% 62.9M/335M [00:00<00:02, 112MB/s]
#
# Downloading model.safetensors:  15% 73.4M/492M [00:01<00:05, 80.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 52.4M/3.44G [00:00<00:39, 84.8MB/s]
# Downloading model.safetensors:  14% 168M/1.22G [00:01<00:08, 130MB/s]
#
# Downloading model.safetensors:  17% 83.9M/492M [00:01<00:05, 78.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  25% 83.9M/335M [00:00<00:02, 115MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 62.9M/3.44G [00:00<00:37, 89.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 73.4M/3.44G [00:00<00:37, 90.5MB/s]
#
# Downloading model.safetensors:  21% 105M/492M [00:01<00:03, 98.5MB/s]
# Downloading model.safetensors:  16% 189M/1.22G [00:01<00:07, 129MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  31% 105M/335M [00:00<00:01, 121MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 83.9M/3.44G [00:01<00:41, 80.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 94.4M/3.44G [00:01<00:43, 76.8MB/s]
#
# Downloading model.safetensors:  23% 115M/492M [00:01<00:05, 66.5MB/s]
# Downloading model.safetensors:  17% 210M/1.22G [00:01<00:10, 97.1MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  38% 126M/335M [00:01<00:02, 88.0MB/s]
#
# Downloading model.safetensors:  26% 126M/492M [00:01<00:05, 73.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 105M/3.44G [00:01<00:42, 78.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  41% 136M/335M [00:01<00:02, 83.7MB/s]
#
# Downloading model.safetensors:  28% 136M/492M [00:01<00:04, 75.0MB/s]
# Downloading model.safetensors:  19% 231M/1.22G [00:01<00:11, 89.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 115M/3.44G [00:01<00:52, 63.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  44% 147M/335M [00:01<00:02, 80.0MB/s]
#
# Downloading model.safetensors:  30% 147M/492M [00:02<00:04, 71.2MB/s]
# Downloading model.safetensors:  20% 241M/1.22G [00:02<00:11, 85.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 126M/3.44G [00:01<00:49, 66.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  47% 157M/335M [00:01<00:02, 75.5MB/s]
#
# Downloading model.safetensors:  32% 157M/492M [00:02<00:05, 65.4MB/s]
# Downloading model.safetensors:  21% 252M/1.22G [00:02<00:14, 68.5MB/s]
#
# Downloading model.safetensors:  34% 168M/492M [00:02<00:05, 63.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 136M/3.44G [00:02<01:00, 54.6MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  50% 168M/335M [00:02<00:02, 63.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  53% 178M/335M [00:02<00:02, 68.1MB/s]
# Downloading model.safetensors:  22% 273M/1.22G [00:02<00:12, 72.9MB/s]
#
# Downloading model.safetensors:  38% 189M/492M [00:02<00:04, 72.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 157M/3.44G [00:02<00:50, 64.8MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  56% 189M/335M [00:02<00:02, 57.5MB/s]
# Downloading model.safetensors:  23% 283M/1.22G [00:02<00:13, 67.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 168M/3.44G [00:02<00:53, 61.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 178M/3.44G [00:02<00:48, 66.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 199M/3.44G [00:02<00:41, 78.6MB/s]
# Downloading model.safetensors:  24% 294M/1.22G [00:03<00:19, 46.5MB/s]
#
# Downloading model.safetensors:  40% 199M/492M [00:03<00:07, 39.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 220M/3.44G [00:02<00:33, 94.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  60% 199M/335M [00:02<00:03, 37.5MB/s]
#
# Downloading model.safetensors:  45% 220M/492M [00:03<00:04, 55.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  66% 220M/335M [00:03<00:01, 57.6MB/s]
# Downloading model.safetensors:  26% 315M/1.22G [00:03<00:14, 60.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 241M/3.44G [00:03<00:31, 102MB/s]
# Downloading model.safetensors:  27% 325M/1.22G [00:03<00:16, 54.8MB/s]
#
# Downloading model.safetensors:  49% 241M/492M [00:03<00:04, 61.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  72% 241M/335M [00:03<00:01, 60.1MB/s]
# Downloading model.safetensors:  28% 336M/1.22G [00:03<00:14, 61.0MB/s]
#
# Downloading model.safetensors:  51% 252M/492M [00:03<00:03, 65.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 262M/3.44G [00:03<00:40, 77.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  75% 252M/335M [00:03<00:01, 63.5MB/s]
# Downloading model.safetensors:  28% 346M/1.22G [00:04<00:16, 53.0MB/s]
#
# Downloading model.safetensors:  53% 262M/492M [00:04<00:04, 56.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 273M/3.44G [00:03<00:47, 66.9MB/s]
# Downloading model.safetensors:  29% 357M/1.22G [00:04<00:14, 60.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  78% 262M/335M [00:03<00:01, 49.9MB/s]
#
# Downloading model.safetensors:  58% 283M/492M [00:04<00:02, 70.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 294M/3.44G [00:03<00:38, 80.8MB/s]
#
# Downloading model.safetensors:  60% 294M/492M [00:04<00:03, 62.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 304M/3.44G [00:04<00:46, 67.5MB/s]
# Downloading model.safetensors:  31% 377M/1.22G [00:04<00:14, 56.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  81% 273M/335M [00:04<00:01, 41.7MB/s]
#
# Downloading model.safetensors:  62% 304M/492M [00:04<00:02, 65.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 315M/3.44G [00:04<00:44, 69.9MB/s]
# Downloading model.safetensors:  32% 388M/1.22G [00:04<00:13, 60.5MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  88% 294M/335M [00:04<00:00, 59.6MB/s]
#
# Downloading model.safetensors:  64% 315M/492M [00:04<00:02, 69.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 336M/3.44G [00:04<00:38, 79.7MB/s]
# Downloading model.safetensors:  33% 398M/1.22G [00:04<00:13, 61.9MB/s]
#
# Downloading model.safetensors:  66% 325M/492M [00:04<00:02, 68.2MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  91% 304M/335M [00:04<00:00, 52.5MB/s]
#
# Downloading model.safetensors:  68% 336M/492M [00:05<00:02, 70.3MB/s]
# Downloading model.safetensors:  34% 409M/1.22G [00:05<00:13, 59.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 346M/3.44G [00:04<00:44, 69.9MB/s]
#
# Downloading model.safetensors:  70% 346M/492M [00:05<00:02, 67.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 357M/3.44G [00:04<00:44, 68.5MB/s]
# Downloading model.safetensors:  35% 430M/1.22G [00:05<00:11, 70.4MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  97% 325M/335M [00:04<00:00, 59.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 367M/3.44G [00:05<00:43, 70.1MB/s]
# Downloading model.safetensors:  36% 440M/1.22G [00:05<00:11, 70.3MB/s]
#
#
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:05<00:00, 60.0MB/s]
#
# Downloading model.safetensors:  72% 357M/492M [00:05<00:02, 58.4MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:05<00:00, 64.5MB/s]
#
#
# Downloading model.safetensors:  75% 367M/492M [00:05<00:02, 61.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 388M/3.44G [00:05<00:40, 74.5MB/s]
# Downloading model.safetensors:  38% 461M/1.22G [00:05<00:09, 77.5MB/s]
#
# Downloading model.safetensors:  77% 377M/492M [00:05<00:01, 66.2MB/s]
# Downloading model.safetensors:  39% 472M/1.22G [00:05<00:09, 78.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 398M/3.44G [00:05<00:44, 67.8MB/s]
#
# Downloading model.safetensors:  79% 388M/492M [00:05<00:01, 69.8MB/s]
# Downloading model.safetensors:  40% 482M/1.22G [00:06<00:09, 79.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 409M/3.44G [00:05<00:44, 67.3MB/s]
#
# Downloading model.safetensors:  81% 398M/492M [00:06<00:01, 70.8MB/s]
# Downloading model.safetensors:  41% 493M/1.22G [00:06<00:08, 82.2MB/s]
#
# Downloading model.safetensors:  83% 409M/492M [00:06<00:01, 73.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 419M/3.44G [00:05<00:45, 66.2MB/s]
# Downloading model.safetensors:  41% 503M/1.22G [00:06<00:08, 81.1MB/s]
# Downloading model.safetensors:  42% 514M/1.22G [00:06<00:08, 84.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 440M/3.44G [00:06<00:37, 79.2MB/s]
#
# Downloading model.safetensors:  87% 430M/492M [00:06<00:00, 78.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 451M/3.44G [00:06<00:35, 83.5MB/s]
# Downloading model.safetensors:  43% 524M/1.22G [00:06<00:10, 66.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 461M/3.44G [00:06<00:34, 86.9MB/s]
#
# Downloading model.safetensors:  92% 451M/492M [00:06<00:00, 85.3MB/s]
# Downloading model.safetensors:  44% 535M/1.22G [00:06<00:09, 72.0MB/s]
#
# Downloading model.safetensors:  94% 461M/492M [00:06<00:00, 82.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 472M/3.44G [00:06<00:39, 75.7MB/s]
# Downloading model.safetensors:  45% 545M/1.22G [00:06<00:09, 71.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 482M/3.44G [00:06<00:36, 80.9MB/s]
#
# Downloading model.safetensors:  96% 472M/492M [00:06<00:00, 82.3MB/s]
# Downloading model.safetensors:  46% 556M/1.22G [00:06<00:08, 76.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 493M/3.44G [00:06<00:34, 85.1MB/s]
# Downloading model.safetensors:  47% 566M/1.22G [00:07<00:08, 80.9MB/s]
#
# Downloading model.safetensors: 100% 492M/492M [00:07<00:00, 88.6MB/s]
# Downloading model.safetensors:  47% 577M/1.22G [00:07<00:07, 83.6MB/s]
#
#
# Downloading model.safetensors: 100% 492M/492M [00:07<00:00, 66.7MB/s]
#
# Downloading model.safetensors:  48% 587M/1.22G [00:07<00:09, 69.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 535M/3.44G [00:07<00:32, 89.4MB/s]
# Downloading model.safetensors:  50% 608M/1.22G [00:07<00:06, 89.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 556M/3.44G [00:07<00:28, 103MB/s]
# Downloading model.safetensors:  52% 629M/1.22G [00:07<00:05, 100MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 577M/3.44G [00:07<00:26, 109MB/s]
# Downloading model.safetensors:  53% 650M/1.22G [00:08<00:06, 89.6MB/s]
# Downloading model.safetensors:  55% 671M/1.22G [00:08<00:05, 109MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 598M/3.44G [00:07<00:31, 89.3MB/s]
# Downloading model.safetensors:  57% 692M/1.22G [00:08<00:04, 122MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 629M/3.44G [00:07<00:24, 116MB/s]
# Downloading model.safetensors:  59% 713M/1.22G [00:08<00:03, 130MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 650M/3.44G [00:08<00:21, 130MB/s]
# Downloading model.safetensors:  60% 734M/1.22G [00:08<00:03, 133MB/s]
# Downloading model.safetensors:  62% 755M/1.22G [00:08<00:03, 116MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 671M/3.44G [00:08<00:29, 94.1MB/s]
# Downloading model.safetensors:  64% 776M/1.22G [00:08<00:03, 116MB/s]
# Downloading model.safetensors:  66% 797M/1.22G [00:09<00:03, 130MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 692M/3.44G [00:08<00:31, 87.7MB/s]
# Downloading model.safetensors:  67% 818M/1.22G [00:09<00:03, 119MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 713M/3.44G [00:08<00:30, 90.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 734M/3.44G [00:09<00:26, 103MB/s]
# Downloading model.safetensors:  69% 839M/1.22G [00:09<00:03, 124MB/s]
# Downloading model.safetensors:  71% 860M/1.22G [00:09<00:02, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 755M/3.44G [00:09<00:24, 109MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 776M/3.44G [00:09<00:21, 122MB/s]
# Downloading model.safetensors:  72% 881M/1.22G [00:09<00:02, 131MB/s]
# Downloading model.safetensors:  74% 902M/1.22G [00:09<00:02, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 797M/3.44G [00:09<00:23, 115MB/s]
# Downloading model.safetensors:  76% 923M/1.22G [00:10<00:02, 132MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 818M/3.44G [00:09<00:22, 119MB/s]
# Downloading model.safetensors:  78% 944M/1.22G [00:10<00:02, 134MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 839M/3.44G [00:09<00:21, 123MB/s]
# Downloading model.safetensors:  79% 965M/1.22G [00:10<00:01, 146MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 860M/3.44G [00:09<00:19, 129MB/s]
# Downloading model.safetensors:  81% 986M/1.22G [00:10<00:01, 156MB/s]
#
#
# Downloading (…)ch_model.safetensors:  26% 881M/3.44G [00:10<00:18, 135MB/s]
# Downloading model.safetensors:  83% 1.01G/1.22G [00:10<00:01, 157MB/s]
#
#
# Downloading (…)ch_model.safetensors:  26% 902M/3.44G [00:10<00:18, 140MB/s]
# Downloading model.safetensors:  85% 1.03G/1.22G [00:10<00:01, 159MB/s]
#
#
# Downloading (…)ch_model.safetensors:  27% 923M/3.44G [00:10<00:17, 148MB/s]
# Downloading model.safetensors:  86% 1.05G/1.22G [00:10<00:01, 147MB/s]
#
#
# Downloading (…)ch_model.safetensors:  27% 944M/3.44G [00:10<00:17, 146MB/s]
# Downloading model.safetensors:  88% 1.07G/1.22G [00:11<00:00, 148MB/s]
#
#
# Downloading (…)ch_model.safetensors:  28% 965M/3.44G [00:10<00:16, 151MB/s]
# Downloading model.safetensors:  90% 1.09G/1.22G [00:11<00:00, 148MB/s]
#
#
# Downloading (…)ch_model.safetensors:  29% 986M/3.44G [00:10<00:15, 155MB/s]
#
#
# Downloading (…)ch_model.safetensors:  29% 1.01G/3.44G [00:10<00:16, 145MB/s]
# Downloading model.safetensors:  91% 1.11G/1.22G [00:11<00:00, 125MB/s]
# Downloading model.safetensors:  93% 1.13G/1.22G [00:11<00:00, 130MB/s]
#
#
# Downloading (…)ch_model.safetensors:  30% 1.03G/3.44G [00:11<00:17, 139MB/s]
#
#
# Downloading (…)ch_model.safetensors:  30% 1.05G/3.44G [00:11<00:19, 125MB/s]
# Downloading model.safetensors:  95% 1.15G/1.22G [00:11<00:00, 115MB/s]
#
#
# Downloading (…)ch_model.safetensors:  31% 1.07G/3.44G [00:11<00:19, 122MB/s]
# Downloading model.safetensors:  97% 1.17G/1.22G [00:11<00:00, 118MB/s]
# Downloading model.safetensors:  98% 1.20G/1.22G [00:12<00:00, 123MB/s]
#
#
# Downloading (…)ch_model.safetensors:  32% 1.09G/3.44G [00:11<00:19, 122MB/s]
# Downloading model.safetensors: 100% 1.22G/1.22G [00:13<00:00, 32.4MB/s]
#
#
# Downloading model.safetensors: 100% 1.22G/1.22G [00:13<00:00, 87.7MB/s]
# Fetching 15 files:  27% 4/15 [00:14<00:41,  3.78s/it]
#
#
# Downloading (…)ch_model.safetensors:  34% 1.15G/3.44G [00:13<00:40, 56.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  34% 1.17G/3.44G [00:14<00:59, 38.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  35% 1.20G/3.44G [00:14<00:47, 46.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  35% 1.22G/3.44G [00:15<01:07, 32.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  36% 1.25G/3.44G [00:17<01:11, 30.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  37% 1.27G/3.44G [00:18<01:21, 26.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  38% 1.31G/3.44G [00:18<00:48, 43.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  39% 1.35G/3.44G [00:18<00:31, 65.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  40% 1.38G/3.44G [00:19<00:43, 46.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  41% 1.42G/3.44G [00:19<00:32, 62.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  42% 1.46G/3.44G [00:19<00:22, 88.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  43% 1.49G/3.44G [00:19<00:17, 108MB/s]
#
#
# Downloading (…)ch_model.safetensors:  44% 1.52G/3.44G [00:19<00:14, 131MB/s]
#
#
# Downloading (…)ch_model.safetensors:  45% 1.55G/3.44G [00:20<00:12, 156MB/s]
#
#
# Downloading (…)ch_model.safetensors:  46% 1.58G/3.44G [00:21<00:27, 68.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  47% 1.63G/3.44G [00:21<00:18, 95.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  48% 1.66G/3.44G [00:21<00:15, 118MB/s]
#
#
# Downloading (…)ch_model.safetensors:  49% 1.69G/3.44G [00:21<00:12, 143MB/s]
#
#
# Downloading (…)ch_model.safetensors:  50% 1.73G/3.44G [00:21<00:09, 174MB/s]
#
#
# Downloading (…)ch_model.safetensors:  51% 1.76G/3.44G [00:21<00:08, 197MB/s]
#
#
# Downloading (…)ch_model.safetensors:  52% 1.79G/3.44G [00:21<00:07, 218MB/s]
#
#
# Downloading (…)ch_model.safetensors:  53% 1.82G/3.44G [00:21<00:06, 237MB/s]
#
#
# Downloading (…)ch_model.safetensors:  54% 1.87G/3.44G [00:22<00:06, 252MB/s]
#
#
# Downloading (…)ch_model.safetensors:  55% 1.90G/3.44G [00:22<00:06, 247MB/s]
#
#
# Downloading (…)ch_model.safetensors:  56% 1.93G/3.44G [00:22<00:05, 259MB/s]
#
#
# Downloading (…)ch_model.safetensors:  57% 1.96G/3.44G [00:22<00:05, 261MB/s]
#
#
# Downloading (…)ch_model.safetensors:  58% 1.99G/3.44G [00:22<00:05, 247MB/s]
#
#
# Downloading (…)ch_model.safetensors:  59% 2.02G/3.44G [00:22<00:05, 248MB/s]
#
#
# Downloading (…)ch_model.safetensors:  60% 2.06G/3.44G [00:22<00:05, 259MB/s]
#
#
# Downloading (…)ch_model.safetensors:  61% 2.09G/3.44G [00:22<00:05, 258MB/s]
#
#
# Downloading (…)ch_model.safetensors:  62% 2.12G/3.44G [00:23<00:05, 251MB/s]
#
#
# Downloading (…)ch_model.safetensors:  63% 2.15G/3.44G [00:23<00:05, 255MB/s]
#
#
# Downloading (…)ch_model.safetensors:  63% 2.18G/3.44G [00:23<00:04, 255MB/s]
#
#
# Downloading (…)ch_model.safetensors:  65% 2.22G/3.44G [00:23<00:04, 278MB/s]
#
#
# Downloading (…)ch_model.safetensors:  66% 2.25G/3.44G [00:23<00:04, 281MB/s]
#
#
# Downloading (…)ch_model.safetensors:  66% 2.29G/3.44G [00:23<00:04, 275MB/s]
#
#
# Downloading (…)ch_model.safetensors:  67% 2.32G/3.44G [00:23<00:04, 272MB/s]
#
#
# Downloading (…)ch_model.safetensors:  68% 2.35G/3.44G [00:23<00:04, 247MB/s]
#
#
# Downloading (…)ch_model.safetensors:  69% 2.38G/3.44G [00:24<00:04, 263MB/s]
#
#
# Downloading (…)ch_model.safetensors:  70% 2.42G/3.44G [00:24<00:03, 285MB/s]
#
#
# Downloading (…)ch_model.safetensors:  71% 2.45G/3.44G [00:24<00:04, 220MB/s]
#
#
# Downloading (…)ch_model.safetensors:  72% 2.49G/3.44G [00:24<00:04, 229MB/s]
#
#
# Downloading (…)ch_model.safetensors:  73% 2.52G/3.44G [00:24<00:04, 219MB/s]
#
#
# Downloading (…)ch_model.safetensors:  74% 2.55G/3.44G [00:24<00:03, 230MB/s]
#
#
# Downloading (…)ch_model.safetensors:  75% 2.58G/3.44G [00:24<00:03, 234MB/s]
#
#
# Downloading (…)ch_model.safetensors:  76% 2.61G/3.44G [00:25<00:03, 252MB/s]
#
#
# Downloading (…)ch_model.safetensors:  77% 2.64G/3.44G [00:25<00:03, 216MB/s]
#
#
# Downloading (…)ch_model.safetensors:  78% 2.67G/3.44G [00:25<00:03, 233MB/s]
#
#
# Downloading (…)ch_model.safetensors:  79% 2.71G/3.44G [00:25<00:03, 242MB/s]
#
#
# Downloading (…)ch_model.safetensors:  80% 2.74G/3.44G [00:25<00:03, 221MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81% 2.77G/3.44G [00:25<00:02, 240MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81% 2.80G/3.44G [00:25<00:02, 255MB/s]
#
#
# Downloading (…)ch_model.safetensors:  82% 2.83G/3.44G [00:26<00:02, 243MB/s]
#
#
# Downloading (…)ch_model.safetensors:  83% 2.86G/3.44G [00:26<00:02, 260MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 2.90G/3.44G [00:26<00:02, 242MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 2.94G/3.44G [00:26<00:02, 243MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 2.98G/3.44G [00:26<00:01, 266MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 3.01G/3.44G [00:26<00:01, 263MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 3.04G/3.44G [00:26<00:01, 263MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 3.07G/3.44G [00:26<00:01, 259MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 3.10G/3.44G [00:27<00:01, 244MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 3.14G/3.44G [00:27<00:01, 247MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 3.17G/3.44G [00:27<00:01, 231MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 3.20G/3.44G [00:27<00:01, 239MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 3.24G/3.44G [00:27<00:00, 267MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 3.27G/3.44G [00:27<00:00, 256MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 3.31G/3.44G [00:27<00:00, 260MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 3.34G/3.44G [00:28<00:00, 237MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 3.38G/3.44G [00:28<00:00, 237MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 3.41G/3.44G [00:28<00:00, 227MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 3.44G/3.44G [00:28<00:00, 121MB/s]
# Fetching 15 files: 100% 15/15 [00:29<00:00,  1.94s/it]
# /usr/local/lib/python3.9/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/transformers/modeling_utils.py:402: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   with safe_open(checkpoint_file, framework="pt") as f:
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 04/08/2023 08:53:26 - INFO - __main__ - Number of class images to sample: 300.
# Generating class images: 100% 75/75 [16:12<00:00, 12.96s/it]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('runwayml/stable-diffusion-v1-5')}
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('outputs')}
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('8013'), PosixPath('http')}
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-6h035hp6fs2d --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(msg)
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/main.py:136: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   warn(msg)
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.9/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /content/diffusers/src/diffusers/configuration_utils.py:203: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Caching latents: 100% 300/300 [01:13<00:00,  4.11it/s]
# 04/08/2023 09:11:07 - INFO - __main__ - ***** Running training *****
# 04/08/2023 09:11:07 - INFO - __main__ -   Num examples = 300
# 04/08/2023 09:11:07 - INFO - __main__ -   Num batches each epoch = 300
# 04/08/2023 09:11:07 - INFO - __main__ -   Num Epochs = 4
# 04/08/2023 09:11:07 - INFO - __main__ -   Instantaneous batch size per device = 1
# 04/08/2023 09:11:07 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 04/08/2023 09:11:07 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/08/2023 09:11:07 - INFO - __main__ -   Total optimization steps = 1000
# Steps:   0% 0/1000 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/xformers/ops/fmha/flash.py:338: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   and inp.query.storage().data_ptr() == inp.key.storage().data_ptr()
# Steps: 100% 1000/1000 [13:59<00:00,  1.20it/s, loss=0.294, lr=1e-6]You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# [*] Weights saved at outputs/1000
# Steps: 100% 1000/1000 [14:19<00:00,  1.16it/s, loss=0.294, lr=1e-6]

# %% [markdown]
# ## Generation

# %% [markdown]
# **You might need to restart the runtime after running this command**

# %%
# Ugly hack, I'm too stupid to import StableDiffusionPipeline from local installation
# If you manage to fix this, let me know :) 
# !pip uninstall diffusers -y
# !pip install diffusers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diffusers
#   Downloading diffusers-0.14.0-py3-none-any.whl (737 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 kB 11.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.10.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from diffusers) (8.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from diffusers) (2022.10.31)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from diffusers) (1.22.4)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.9/dist-packages (from diffusers) (6.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from diffusers) (3.10.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from diffusers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.10.0->diffusers) (23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->diffusers) (2022.12.7)
# Installing collected packages: huggingface-hub, diffusers
# Successfully installed diffusers-0.14.0 huggingface-hub-0.13.4

# %% [markdown]
# - Ideas for better prompts: https://stablediffusionweb.com/prompts

# %%
# %cd /content
import torch
import random
from diffusers import StableDiffusionPipeline

model_id = "outputs/1000"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16).to("cuda")

example_prompts = [
"close-up photo of zwx person in a suit",
"closeup portrait of zwx person in a suit, highly detailed, with future city skyline in the background",
"Professional headshot of zwx person inside a modern office building, highly detailed, business, open eyes",
"LinkedIn profile picture of zwx person, close up, professional, businessman, blue suit, 8k"
]

num_images = 10
for i in range(num_images):
    prompt = example_prompts[random.randint(0, len(example_prompts) - 1)]
    image = pipe(prompt, num_inference_steps=50, guidance_scale=7.5).images[0]
    image.save(f"profile_{i}.png")
# Out:
# /content
# The config attributes {'class_embeddings_concat': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# /usr/local/lib/python3.9/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
