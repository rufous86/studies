# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.5.0)

# %%
from catboost import CatBoostClassifier
import pandas as pd

# %%
path = '/content/drive/MyDrive/Study/hackathons/datasecrets_first_cup/'

# %%
df_train = pd.read_csv(path + 'data/train_target.csv')
df_train
# Out:
#                              ClientUUId  Id OrderType  \
# 0      000D3A20F23EA95811E7B99F3ED09FC8   7       2,3
# 1      000D3A20F23EA95811E7B99F3ED09FC8   6     1,2,3
# 2      000D3A20F23EA95811E7BD373E79565E   5       2,3
# 3      000D3A20F23EA95811E7BD373E79565E   5     1,2,3
# 4      000D3A20F23EA95811E7BDAE71CD3F33   6       2,3
# ...                                 ...  ..       ...
# 27736  82EDBCD6CE60978F11EDC591DCA75401   5       2,3
# 27737  82EDBCD6CE60978F11EDC591DCA75401   5     1,2,3
# 27738  82F78FC7401A9ADD11EDFA15A350D31F   6       2,3
# 27739  8606F5E4CA39BF7211EE517E6E1D90B7   5       2,3
# 27740  8606F5E4CA39BF7211EE517E6E1D90B7   5     1,2,3
#
#                  LocalBeginDate              LocalEndDate  OrderPrice  \
# 0      2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z         699
# 1      2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z        1249
# 2      2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z         799
# 3      2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z        1249
# 4      2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z         699
# ...                         ...                       ...         ...
# 27736  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z         799
# 27737  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z        1249
# 27738  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z         799
# 27739  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z         749
# 27740  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z        1249
#
#        Discount  apply_promo
# 0           200            0
# 1            25            0
# 2           200            0
# 3           250            0
# 4            30            0
# ...         ...          ...
# 27736       200            0
# 27737       250            0
# 27738        20            0
# 27739       200            0
# 27740       250            0
#
# [27741 rows x 8 columns]

# %%
df_orders = pd.read_csv(path + 'data/orders.csv')
df_orders
# Out:
#                                OrderUUId  addressId  deliverySectorId  \
# 0       020DD76CCD949AE011EDE031ED5D76FD        NaN               NaN
# 1       02164D9B0F67BC3311EE610987AF48C7        0.0               0.0
# 2       02164D9B0F67BC3311EE610987AF48C7        0.0               0.0
# 3       02164D9B0F67BC3311EE610987AF48C7        0.0               0.0
# 4       02164D9B0F67BC3311EE610987AF48C7        0.0               0.0
# ...                                  ...        ...               ...
# 611734  FEE4A40E62DA936011EE0DA9C66D87C8        0.0               0.0
# 611735  FEE4A40E62DA936011EE0DA9C66D87C8        0.0               0.0
# 611736  FEE7759E6F988C7111EDC1BDEEDF6376  9723140.0            4103.0
# 611737  FEE7759E6F988C7111EDC1BDEEDF6376  9723140.0            4103.0
# 611738  FEE7759E6F988C7111EDC1BDEEDF6376  9723140.0            4103.0
#
#                               ClientUUId        Date  \
# 0       000D3AAC9DCABB2E11EBE0614C89D044  2023-04-21
# 1       000D3A21DA51A81411EAF10674007D74  2023-10-02
# 2       000D3A21DA51A81411EAF10674007D74  2023-10-02
# 3       000D3A21DA51A81411EAF10674007D74  2023-10-02
# 4       000D3A21DA51A81411EAF10674007D74  2023-10-02
# ...                                  ...         ...
# 611734  000D3A39D824A82E11EA2BB7F48841A0  2023-06-18
# 611735  000D3A39D824A82E11EA2BB7F48841A0  2023-06-18
# 611736  000D3A22FA54A81411E9BC5EF27EE5BF  2023-03-24
# 611737  000D3A22FA54A81411E9BC5EF27EE5BF  2023-03-24
# 611738  000D3A22FA54A81411E9BC5EF27EE5BF  2023-03-24
#
#                         SaleDate                          UnitUUId  NewClient  \
# 0       2023-04-21T20:51:26.000Z  000D3A2480C380DA11E692CFB9F92484          0
# 1       2023-10-02T21:31:32.000Z  000D3A26B5B080DF11E745FD0474B95C          0
# 2       2023-10-02T21:31:32.000Z  000D3A26B5B080DF11E745FD0474B95C          0
# 3       2023-10-02T21:31:32.000Z  000D3A26B5B080DF11E745FD0474B95C          0
# 4       2023-10-02T21:31:32.000Z  000D3A26B5B080DF11E745FD0474B95C          0
# ...                          ...                               ...        ...
# 611734  2023-06-18T15:34:13.000Z  000D3A22FA54A81411E95B9E966DC9B2          0
# 611735  2023-06-18T15:34:13.000Z  000D3A22FA54A81411E95B9E966DC9B2          0
# 611736  2023-03-24T15:50:51.000Z  000D3A24D2B7A94311E8706B7529EBFD          0
# 611737  2023-03-24T15:50:51.000Z  000D3A24D2B7A94311E8706B7529EBFD          0
# 611738  2023-03-24T15:50:51.000Z  000D3A24D2B7A94311E8706B7529EBFD          0
#
#         ClientOrderNumber                       ProductUUId  CategoryId  \
# 0                      18  000D3A240C71BE9A11E719BE2AB264A6           4
# 1                      29  11EC9AABAD354BE051CCF1EE1F83A8D0           1
# 2                      29  11EB846583CB3BDEA80D1A7F2E184D40           1
# 3                      29  000D3A240C71BE9A11E719BE2AB267FD           4
# 4                      29  000D3A240C71BE9A11E719BE2AB264A6           4
# ...                   ...                               ...         ...
# 611734                 55  11EA5EE49DCBD9124A66F764872C8E20           1
# 611735                 55  000D3A39D824A82E11E9A18231161F87           1
# 611736                 28  000D3A240C71BE9A11E719BE2AB2D427           3
# 611737                 28  11ED08AA93691DC615EE94EB19CD7070           3
# 611738                 28  11ED276CA17B3D3016833EF686833390           3
#
#         ProductTotalPrice  MenuPrice  OrderState  OrderPaymentType  \
# 0                     1.0       45.0           4                 2
# 1                   485.0      485.0           4                 2
# 2                   589.0      589.0           4                 2
# 3                    45.0       45.0           4                 2
# 4                    45.0       45.0           4                 2
# ...                   ...        ...         ...               ...
# 611734              594.0      719.0           4                 2
# 611735              395.0      479.0           4                 2
# 611736              169.0      169.0           4                 2
# 611737              189.0      189.0           4                 2
# 611738              199.0      199.0           4                 2
#
#         OrderTotalPrice  OrderType  apply_promo
# 0                   1.0          3            0
# 1                1164.0          1            0
# 2                1164.0          1            0
# 3                1164.0          1            0
# 4                1164.0          1            0
# ...                 ...        ...          ...
# 611734           1509.0          1            0
# 611735           1509.0          1            0
# 611736            557.0          1            0
# 611737            557.0          1            0
# 611738            557.0          1            0
#
# [611739 rows x 18 columns]

# %%
print('df_train ClientUUId & df_orders ClientUUId\t', len(set(df_train['ClientUUId']) & set(df_orders['ClientUUId'])))
print('df_train ClientUUId\t\t\t\t', len(set(df_train['ClientUUId'])))
print('df_orders ClientUUId\t\t\t\t', len(set(df_orders['ClientUUId'])))
# Out:
# df_train ClientUUId & df_orders ClientUUId	 10023
# df_train ClientUUId				 18598
# df_orders ClientUUId				 16337

# %%
df_merge = pd.merge(df_orders, df_train, how='outer', on='ClientUUId')
print(df_merge[['apply_promo_x', 'apply_promo_y']].isna().mean())
df_merge
# Out:
# apply_promo_x    0.015549
# apply_promo_y    0.287105
# dtype: float64
#                                OrderUUId  addressId  deliverySectorId  \
# 0       020DD76CCD949AE011EDE031ED5D76FD        NaN               NaN
# 1       020DD76CCD949AE011EDE031ED5D76FD        NaN               NaN
# 2       7E56F93B9996989111EE287E2FB97BE3        NaN               NaN
# 3       7E56F93B9996989111EE287E2FB97BE3        NaN               NaN
# 4       7E56F93B9996989111EE287E2FB97BE3        NaN               NaN
# ...                                  ...        ...               ...
# 818106                               NaN        NaN               NaN
# 818107                               NaN        NaN               NaN
# 818108                               NaN        NaN               NaN
# 818109                               NaN        NaN               NaN
# 818110                               NaN        NaN               NaN
#
#                               ClientUUId        Date  \
# 0       000D3AAC9DCABB2E11EBE0614C89D044  2023-04-21
# 1       000D3AAC9DCABB2E11EBE0614C89D044  2023-04-21
# 2       000D3AAC9DCABB2E11EBE0614C89D044  2023-07-22
# 3       000D3AAC9DCABB2E11EBE0614C89D044  2023-07-22
# 4       000D3AAC9DCABB2E11EBE0614C89D044  2023-07-22
# ...                                  ...         ...
# 818106  7E595BF1EB05B56E11EDB9C6FE6B0F7B         NaN
# 818107  7EF11191557BBC0511ED996991D7EAAA         NaN
# 818108  82F78FC7401A9ADD11EDFA15A350D31F         NaN
# 818109  8606F5E4CA39BF7211EE517E6E1D90B7         NaN
# 818110  8606F5E4CA39BF7211EE517E6E1D90B7         NaN
#
#                         SaleDate                          UnitUUId  NewClient  \
# 0       2023-04-21T20:51:26.000Z  000D3A2480C380DA11E692CFB9F92484        0.0
# 1       2023-04-21T20:51:26.000Z  000D3A2480C380DA11E692CFB9F92484        0.0
# 2       2023-07-22T22:26:45.000Z  000D3A38B306A94411E8924C02E134A4        0.0
# 3       2023-07-22T22:26:45.000Z  000D3A38B306A94411E8924C02E134A4        0.0
# 4       2023-07-22T22:26:45.000Z  000D3A38B306A94411E8924C02E134A4        0.0
# ...                          ...                               ...        ...
# 818106                       NaN                               NaN        NaN
# 818107                       NaN                               NaN        NaN
# 818108                       NaN                               NaN        NaN
# 818109                       NaN                               NaN        NaN
# 818110                       NaN                               NaN        NaN
#
#         ClientOrderNumber                       ProductUUId  ...  \
# 0                    18.0  000D3A240C71BE9A11E719BE2AB264A6  ...
# 1                    18.0  000D3A240C71BE9A11E719BE2AB264A6  ...
# 2                    20.0  11EBADD4B90B8B4F0F2EF40F8BDAB3D0  ...
# 3                    20.0  11EBADD4B90B8B4F0F2EF40F8BDAB3D0  ...
# 4                    20.0  11ECB9E3A88791176470AA6E3C42AC80  ...
# ...                   ...                               ...  ...
# 818106                NaN                               NaN  ...
# 818107                NaN                               NaN  ...
# 818108                NaN                               NaN  ...
# 818109                NaN                               NaN  ...
# 818110                NaN                               NaN  ...
#
#         OrderTotalPrice  OrderType_x  apply_promo_x   Id  OrderType_y  \
# 0                   1.0          3.0            0.0  5.0          2,3
# 1                   1.0          3.0            0.0  5.0        1,2,3
# 2                 199.0          2.0            0.0  5.0          2,3
# 3                 199.0          2.0            0.0  5.0        1,2,3
# 4                 199.0          2.0            0.0  5.0          2,3
# ...                 ...          ...            ...  ...          ...
# 818106              NaN          NaN            NaN  6.0        1,2,3
# 818107              NaN          NaN            NaN  7.0          2,3
# 818108              NaN          NaN            NaN  6.0          2,3
# 818109              NaN          NaN            NaN  5.0          2,3
# 818110              NaN          NaN            NaN  5.0        1,2,3
#
#                   LocalBeginDate              LocalEndDate  OrderPrice  \
# 0       2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z       699.0
# 1       2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z      1099.0
# 2       2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z       699.0
# 3       2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z      1099.0
# 4       2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z       699.0
# ...                          ...                       ...         ...
# 818106  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z      1249.0
# 818107  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z       799.0
# 818108  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z       799.0
# 818109  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z       749.0
# 818110  2023-11-02T00:00:00.000Z  2023-11-05T23:59:00.000Z      1249.0
#
#         Discount apply_promo_y
# 0          150.0           0.0
# 1          250.0           0.0
# 2          150.0           0.0
# 3          250.0           0.0
# 4          150.0           0.0
# ...          ...           ...
# 818106      30.0           0.0
# 818107     200.0           0.0
# 818108      20.0           0.0
# 818109     200.0           0.0
# 818110     250.0           0.0
#
# [818111 rows x 25 columns]

# %%
df_clients_promo_october = pd.read_csv(path + 'data/clients_promo_october.csv')
df_clients_promo_october
# Out:
#                               ClientUUId  Id            LocalBeginDate  \
# 0       000D3A20F23EA95811E7B7104AC23CD3   6  2023-10-12T00:00:00.000Z
# 1       000D3A20F23EA95811E7B7D79FAABAA1   5  2023-10-12T00:00:00.000Z
# 2       000D3A20F23EA95811E7B8BD71C73877   7  2023-10-12T00:00:00.000Z
# 3       000D3A20F23EA95811E7B99F3ED09FC8   6  2023-10-12T00:00:00.000Z
# 4       000D3A20F23EA95811E7BD373E79565E   6  2023-10-12T00:00:00.000Z
# ...                                  ...  ..                       ...
# 477270  82EDCEB57826A0A811ED680C33F09E52   6  2023-10-30T00:00:00.000Z
# 477271  82F78FC7401A9ADD11EDFA15A350D31F   5  2023-10-30T00:00:00.000Z
# 477272  82F78FC7401AA4A811EDF992437D8CC6   5  2023-10-30T00:00:00.000Z
# 477273  82F9662CB356B7E011EE167FC961059B   6  2023-10-30T00:00:00.000Z
# 477274  8606F5E4CA39BF7211EE517E6E1D90B7   6  2023-10-30T00:00:00.000Z
#
#                     LocalEndDate OrderType  OrderPrice  Discount
# 0       2023-10-15T23:59:00.000Z     1,2,3        1299        25
# 1       2023-10-15T23:59:00.000Z     1,2,3        1299       300
# 2       2023-10-15T23:59:00.000Z     1,2,3        1249       200
# 3       2023-10-15T23:59:00.000Z     1,2,3        1249        30
# 4       2023-10-15T23:59:00.000Z     1,2,3        1299        20
# ...                          ...       ...         ...       ...
# 477270  2023-11-01T23:59:00.000Z       2,3         799        20
# 477271  2023-11-01T23:59:00.000Z       2,3         799       200
# 477272  2023-11-01T23:59:00.000Z       2,3         799       200
# 477273  2023-11-01T23:59:00.000Z       2,3         799        20
# 477274  2023-11-01T23:59:00.000Z       2,3         749        25
#
# [477275 rows x 7 columns]

# %%
df_merge_promo = pd.merge(df_merge, df_clients_promo_october, how='outer', on='ClientUUId')

# %%
df_merge_promo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13347707 entries, 0 to 13347706
# Data columns (total 31 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   OrderUUId          object
#  1   addressId          float64
#  2   deliverySectorId   float64
#  3   ClientUUId         object
#  4   Date               object
#  5   SaleDate           object
#  6   UnitUUId           object
#  7   NewClient          float64
#  8   ClientOrderNumber  float64
#  9   ProductUUId        object
#  10  CategoryId         float64
#  11  ProductTotalPrice  float64
#  12  MenuPrice          float64
#  13  OrderState         float64
#  14  OrderPaymentType   float64
#  15  OrderTotalPrice    float64
#  16  OrderType_x        float64
#  17  apply_promo_x      float64
#  18  Id_x               float64
#  19  OrderType_y        object
#  20  LocalBeginDate_x   object
#  21  LocalEndDate_x     object
#  22  OrderPrice_x       float64
#  23  Discount_x         float64
#  24  apply_promo_y      float64
#  25  Id_y               int64
#  26  LocalBeginDate_y   object
#  27  LocalEndDate_y     object
#  28  OrderType          object
#  29  OrderPrice_y       int64
#  30  Discount_y         int64
# dtypes: float64(16), int64(3), object(12)
# memory usage: 3.1+ GB

# %%
df_merge_promo[['apply_promo_x', 'apply_promo_y']].isna().mean()
# Out:
# apply_promo_x    0.020638
# apply_promo_y    0.291580
# dtype: float64
